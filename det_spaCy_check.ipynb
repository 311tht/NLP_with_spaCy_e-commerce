# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load("en_core_web_sm")
my_text = "Looking for a pair of durable running shoes with good arch support on sale."
doc = nlp(my_text)
for token in doc:
    
    if ("dobj" in token.dep_):
        for child in token.children:
            print(child)
        subtree = list(token.subtree)
        start = subtree[0].i
        end = subtree[-1].i + 1
        extract = doc[start:end]
        product = token
        print(token.text)
        print(len(relations))
        print(f'RESULT DOBJ: {extract}')
        print()
        
    elif ("pobj" in token.dep_):
        for child in token.children:
            print(child)
        subtree = list(token.subtree)
        start = subtree[0].i
        end = subtree[-1].i + 1
        extract = doc[start:end]
        product = token
        print(token.text)
        print(len(relations))
        print(f'RESULT POBJ: {extract}')
        print()
# Out:
# a
# of
# with
# pair
# 0
# RESULT POBJ: a pair of durable running shoes with good arch support on sale
#
# durable
# running
# shoes
# 0
# RESULT POBJ: durable running shoes
#
# good
# arch
# on
# support
# 0
# RESULT POBJ: good arch support on sale
#
# sale
# 0
# RESULT POBJ: sale

# %%
displacy.render(doc)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="cae853b4f4a244cc88f8d4ba0e7f5dbc-0" class="displacy" width="2500" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Looking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
# ...

# %%
def get_subject_phrase(doc):
    for token in doc:
            subtree = list(token.subtree)
            start = subtree[0].i
            end = subtree[-1].i + 1
            return doc[start:end]

# %%
get_subject_phrase(doc)
# Out:
# Looking for a pair of durable running shoes with good arch support on sale.
